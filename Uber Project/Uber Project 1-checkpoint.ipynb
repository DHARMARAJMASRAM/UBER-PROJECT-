# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Uber Request.csv',encoding='latin1')

# %%
df
# Out:
#       ï»¿Request id Pickup point  Driver id             Status  \
# 0               619      Airport        1.0     Trip Completed
# 1               867      Airport        1.0     Trip Completed
# 2              1807         City        1.0     Trip Completed
# 3              2532      Airport        1.0     Trip Completed
# 4              3112         City        1.0     Trip Completed
# ...             ...          ...        ...                ...
# 6740           6745         City        NaN  No Cars Available
# 6741           6752      Airport        NaN  No Cars Available
# 6742           6751         City        NaN  No Cars Available
# 6743           6754         City        NaN  No Cars Available
# 6744           6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# ...

# %% [markdown]
# ### Top 5 Rows

# %%
df.head()
# Out:
#    ï»¿Request id Pickup point  Driver id          Status    Request timestamp  \
# 0            619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1            867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2           1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3           2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4           3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %% [markdown]
# ### Last 5 Rows

# %%
df.tail()
# Out:
#       ï»¿Request id Pickup point  Driver id             Status  \
# 6740           6745         City        NaN  No Cars Available
# 6741           6752      Airport        NaN  No Cars Available
# 6742           6751         City        NaN  No Cars Available
# 6743           6754         City        NaN  No Cars Available
# 6744           6753      Airport        NaN  No Cars Available
#
#         Request timestamp Drop timestamp
# 6740  15-07-2016 23:49:03            NaN
# 6741  15-07-2016 23:50:05            NaN
# 6742  15-07-2016 23:52:06            NaN
# 6743  15-07-2016 23:54:39            NaN
# 6744  15-07-2016 23:55:03            NaN

# %% [markdown]
# ### Dimension of Data Set

# %%
df.shape
# Out:
# (6745, 6)

# %% [markdown]
# ### Size of Data Set

# %%
df.size
# Out:
# 40470

# %% [markdown]
# ### Information of the Data Set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ï»¿Request id      6745 non-null   int64
#  1   Pickup point       6745 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             6745 non-null   object
#  4   Request timestamp  6745 non-null   object
#  5   Drop timestamp     2831 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 316.3+ KB

# %% [markdown]
# ### show missing value

# %%
df.isnull()
# Out:
#       ï»¿Request id  Pickup point  Driver id  Status  Request timestamp  \
# 0             False         False      False   False              False
# 1             False         False      False   False              False
# 2             False         False      False   False              False
# 3             False         False      False   False              False
# 4             False         False      False   False              False
# ...             ...           ...        ...     ...                ...
# 6740          False         False       True   False              False
# 6741          False         False       True   False              False
# 6742          False         False       True   False              False
# 6743          False         False       True   False              False
# 6744          False         False       True   False              False
#
#       Drop timestamp
# 0              False
# 1              False
# 2              False
# ...

# %%
df.isnull().values.sum()
# Out:
# 6564

# %%
df.isnull().sum()
# Out:
# ï»¿Request id           0
# Pickup point            0
# Driver id            2650
# Status                  0
# Request timestamp       0
# Drop timestamp       3914
# dtype: int64

# %% [markdown]
# ### summary of original data

# %%
df.describe()
# Out:
#        ï»¿Request id    Driver id
# count    6745.000000  4095.000000
# mean     3384.644922   149.501343
# std      1955.099667    86.051994
# min         1.000000     1.000000
# 25%      1691.000000    75.000000
# 50%      3387.000000   149.000000
# 75%      5080.000000   224.000000
# max      6766.000000   300.000000

# %%
df
# Out:
#       ï»¿Request id Pickup point  Driver id             Status  \
# 0               619      Airport        1.0     Trip Completed
# 1               867      Airport        1.0     Trip Completed
# 2              1807         City        1.0     Trip Completed
# 3              2532      Airport        1.0     Trip Completed
# 4              3112         City        1.0     Trip Completed
# ...             ...          ...        ...                ...
# 6740           6745         City        NaN  No Cars Available
# 6741           6752      Airport        NaN  No Cars Available
# 6742           6751         City        NaN  No Cars Available
# 6743           6754         City        NaN  No Cars Available
# 6744           6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# ...

# %%
df['Pickup point'].value_counts()
# Out:
# City       3507
# Airport    3238
# Name: Pickup point, dtype: int64

# %%
df['Pickup point'].value_counts().plot(kind='bar')
plt.ylabel('Value counts')
plt.xlabel('Pickup point')
plt.show()

# %%
df['Pickup point'].value_counts().plot(kind='bar',color='g')
plt.ylabel('Value counts')
plt.xlabel('Pickup point')
plt.show()

# %% [markdown]
# ### Pie chart

# %%
df
# Out:
#       ï»¿Request id Pickup point  Driver id             Status  \
# 0               619      Airport        1.0     Trip Completed
# 1               867      Airport        1.0     Trip Completed
# 2              1807         City        1.0     Trip Completed
# 3              2532      Airport        1.0     Trip Completed
# 4              3112         City        1.0     Trip Completed
# ...             ...          ...        ...                ...
# 6740           6745         City        NaN  No Cars Available
# 6741           6752      Airport        NaN  No Cars Available
# 6742           6751         City        NaN  No Cars Available
# 6743           6754         City        NaN  No Cars Available
# 6744           6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# ...

# %%
df['Status'].value_counts()
# Out:
# Trip Completed       2831
# No Cars Available    2650
# Cancelled            1264
# Name: Status, dtype: int64

# %%
df['Status'].value_counts().plot(kind='pie',autopct='%0.2f%%')
plt.show()

# %%
df['Status'].value_counts().plot(kind='pie',autopct='%0.2f%%',explode=[0.1,0.1,0.1])
plt.show()

# %%
df
# Out:
#       ï»¿Request id Pickup point  Driver id             Status  \
# 0               619      Airport        1.0     Trip Completed
# 1               867      Airport        1.0     Trip Completed
# 2              1807         City        1.0     Trip Completed
# 3              2532      Airport        1.0     Trip Completed
# 4              3112         City        1.0     Trip Completed
# ...             ...          ...        ...                ...
# 6740           6745         City        NaN  No Cars Available
# 6741           6752      Airport        NaN  No Cars Available
# 6742           6751         City        NaN  No Cars Available
# 6743           6754         City        NaN  No Cars Available
# 6744           6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# ...

# %%
df['Driver id'].value_counts()
# Out:
# 27.0     22
# 176.0    21
# 177.0    21
# 84.0     21
# 22.0     21
#          ..
# 208.0     8
# 123.0     7
# 42.0      7
# 265.0     6
# 300.0     6
# Name: Driver id, Length: 300, dtype: int64

# %%
df
# Out:
#       ï»¿Request id Pickup point  Driver id             Status  \
# 0               619      Airport        1.0     Trip Completed
# 1               867      Airport        1.0     Trip Completed
# 2              1807         City        1.0     Trip Completed
# 3              2532      Airport        1.0     Trip Completed
# 4              3112         City        1.0     Trip Completed
# ...             ...          ...        ...                ...
# 6740           6745         City        NaN  No Cars Available
# 6741           6752      Airport        NaN  No Cars Available
# 6742           6751         City        NaN  No Cars Available
# 6743           6754         City        NaN  No Cars Available
# 6744           6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# ...

# %%
df.sample(10)
# Out:
#       ï»¿Request id Pickup point  Driver id             Status  \
# 3818            589      Airport      234.0          Cancelled
# 1963           5430         City      205.0     Trip Completed
# 3180            324         City       85.0          Cancelled
# 146            3413      Airport       16.0     Trip Completed
# 3264           4245         City      105.0          Cancelled
# 5429           3706      Airport        NaN  No Cars Available
# 2095            700         City      221.0     Trip Completed
# 4001           2387         City      278.0          Cancelled
# 5585           4001         City        NaN  No Cars Available
# 3783           4641         City      226.0          Cancelled
#
#         Request timestamp       Drop timestamp
# 3818      11/7/2016 11:19                  NaN
# 1963  15-07-2016 02:35:11  15-07-2016 03:25:33
# 3180       11/7/2016 7:40                  NaN
# 146   13-07-2016 15:32:01  13-07-2016 16:45:44
# ...

# %% [markdown]
# #### bar plot

# %%
sns.barplot(data=df,x='Pickup point',y='Driver id')
plt.show()

# %%
plt.figure(figsize=(10,6))
df.groupby('Pickup point')['Driver id'].sum().plot(kind='bar')
plt.show()

# %%
df
# Out:
#       ï»¿Request id Pickup point  Driver id             Status  \
# 0               619      Airport        1.0     Trip Completed
# 1               867      Airport        1.0     Trip Completed
# 2              1807         City        1.0     Trip Completed
# 3              2532      Airport        1.0     Trip Completed
# 4              3112         City        1.0     Trip Completed
# ...             ...          ...        ...                ...
# 6740           6745         City        NaN  No Cars Available
# 6741           6752      Airport        NaN  No Cars Available
# 6742           6751         City        NaN  No Cars Available
# 6743           6754         City        NaN  No Cars Available
# 6744           6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# ...

# %%
df.columns
# Out:
# Index(['ï»¿Request id', 'Pickup point', 'Driver id', 'Status',
#        'Request timestamp', 'Drop timestamp'],
#       dtype='object')

# %%
pd.crosstab(df['Pickup point'],df['Status'])
# Out:
# Status        Cancelled  No Cars Available  Trip Completed
# Pickup point
# Airport             198               1713            1327
# City               1066                937            1504

# %%
pd.crosstab(df['Pickup point'],df['Status']).plot(kind='bar')
plt.grid()
plt.show()

# %% [markdown]
# ### Stacked Bar Graph

# %%
pd.crosstab(df['Pickup point'],df['Status'])
# Out:
# Status        Cancelled  No Cars Available  Trip Completed
# Pickup point
# Airport             198               1713            1327
# City               1066                937            1504

# %%
pd.crosstab(df['Pickup point'],df['Status']).plot(kind='bar',stacked=True)
plt.show()
